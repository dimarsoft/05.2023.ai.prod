# %% [markdown]
# **Домашнее задание**
#
# 1. Создайте виртуальную машину на YandexCloud
# 2. Настройте пользователя и права доступа
# 3. Напишите произвольное приложение (можно взять приложение из занятия)
# 4. В качестве ответа на задание пришлите ссылку на страницу результат

# %%
# !git clone https://github.com/dimarsoft/05.2023.ai.prod.git

# %%
запускаем lesson_2/forex_currency.py
sudo nohup python3 ./github/05.2023.ai.prod/lesson_2/forex_currency.py > log.txt 2>&1

# %%
http://127.0.0.1:5010/ доступен выбор валют для просмотра курса
http://127.0.0.1:5010/forex - Сегодня 2023-05-19 сервис не доступен!!!
http://127.0.0.1:5010/currency - Сегодня 2023-05-19 за 1 евро дают: 1 долларов 9 центов, как на занятии

# %%
Сервер на yandexCloud запускаю при необходимости. сейчас выключен.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
